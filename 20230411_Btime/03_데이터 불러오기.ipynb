# %% [markdown]
# # 데이터 불러오기/살펴보기
#
# ### 주요 내용
#
# 1. csv, xlsx 파일 불러오기
# 2. 데이터 살펴보기
# 3. DRM 보안 파일 불러오기
#
# <br>
#
# ### 목표
# 1. 분석에 필요한 데이터를 python으로 불러올 수 있다.
# 2. 데이터의 일부나 특성을 확인할 수 있다.
#
#
# <br>
# <hr>
# <br>

# %% [markdown]
# ## 1. 파일 불러와서 살펴보기
#
# **pandas** 라이브러리의 *read_csv()* 등의 함수를 활용해서 데이터 불러오기 가능
# 아래의 표현들을 활용해서 데이터 파일의 경로 지정 필요
#
# * `/` : **root**. Windows에서는 C:\
# * `~/` : 사용자 폴더. Windows에서는 C:\Users\사용자계정이름
# * `./` : 현재 작업 폴더(working directory), 별도로 작업하지 않은 경우 생략 가능
# * `../` : 현재 폴더의 상위 폴더
#
#
# `바탕화면`처럼 익숙한 곳에 새로운 폴더를 만들고, 데이터 파일을 옮겨서 작업하는 것을 추천

# %%
# 현재 작업 폴더 확인
    ## print working directory
# %pwd
# Out:
# 'C:\\Users\\jhpark\\Desktop\\7_fastcampus\\Python으로 시작하는 데이터 분석_박종현'

# %% [markdown]
# <br>
#
# ### 1.1. CSV 파일 불러오기
#
# **pandas** 라이브러리 불러오기

# %%
import pandas as pd

# %%
# pandas의 read_csv( ) 활용
#df_ins= pd.read_csv("./data/insurance.csv")
df_ins= pd.read_csv("data/insurance.csv")
df_ins  
    ## 경로가 중요! 
    ## ./ : ipynb 노트북 파일 폴더
    ## ./ 생략 가능
    ## Tab으로 자동 완성 기능 활용 가능
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
# 타입 확인
type(df_ins)
    ## "DataFrame"
# Out:
# pandas.core.frame.DataFrame

# %%
# 메서드의 확인(마침표 뒤에서 Tab 누르기)
df_ins.

# %% [markdown]
# <br>
#
# ### 1.2. 데이터 살펴보기

# %%
# head( )로 앞 몇개 관측치 확인
df_ins.head(5)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# tail( )로 끝 몇 개 관측치 확인
df_ins.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
# 관측치/ 변수 개수 확인
df_ins.shape
# Out:
# (1338, 7)

# %%
# 관측치 개수만 확인
df_ins.shape[1]
# Out:
# 7

# %%
# index(행 이름) 확인
df_ins.index
# Out:
# RangeIndex(start=0, stop=1338, step=1)

# %%
# columns(변수 이름) 확인
df_ins.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
# 변수 형식 확인
df_ins.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %% [markdown]
# <br>
#
# #### [실습] data 폴더의 PulseRates.csv를 불러와서 df_pr로 저장하기
#
# 이후 자유롭게 데이터 탐색하기

# %%
df_pr= pd.read_csv("data/PulseRates.csv")
df_pr
# Out:
#      Height  Weight  Age  Gender  Smokes  Alcohol  Exercise  Ran  Pulse1  \
# 0       173    57.0   18       2       2        1         2    2    86.0
# 1       179    58.0   19       2       2        1         2    1    82.0
# 2       167    62.0   18       2       2        1         1    1    96.0
# 3       195    84.0   18       1       2        1         1    2    71.0
# 4       173    64.0   18       2       2        1         3    2    90.0
# ..      ...     ...  ...     ...     ...      ...       ...  ...     ...
# 105      93    27.0   19       2       2        2         3    2   119.0
# 106     161    43.0   19       2       2        2         3    2    90.0
# 107     182    60.0   22       1       2        1         3    2    86.0
# 108     170    65.0   18       1       2        1         1    2    69.0
# 109     185    85.0   19       1       2        1         2    2    75.0
#
#      Pulse2  Year
# 0      88.0    93
# 1     150.0    93
# 2     176.0    93
# 3      73.0    93
# 4      88.0    93
# ..      ...   ...
# 105   120.0    98
# 106    89.0    98
# 107    84.0    98
# 108    64.0    98
# 109    68.0    98
#
# [110 rows x 11 columns]

# %%
df_pr.dtypes
# Out:
# Height        int64
# Weight      float64
# Age           int64
# Gender        int64
# Smokes        int64
# Alcohol       int64
# Exercise      int64
# Ran           int64
# Pulse1      float64
# Pulse2      float64
# Year          int64
# dtype: object

# %% [markdown]
# #### [참고] Encoding 지정 및 index, header 지정

# %%
# 인코딩(글자 저장 방법) 오류 발생
    ## UnicodeDecodeError  'utf-8' codec can't decode byte 0xbc in position 1: invalid start byte
pd.read_csv('data/고용지표_20221115084415.csv')
# Out:
#    ����(1)       2021. 08 2021. 08.1 2021. 08.2       2021. 09 2021. 09.1  \
# 0  ����(1)  ����Ȱ��������      �Ǿ���      �����  ����Ȱ��������      �Ǿ���
# 1      �հ�           61.7        4.0       59.2           61.9        3.6
# 2     ����           70.0        4.1       67.1           70.3        3.8
# 3     ����           54.2        3.9       52.1           54.3        3.4
#
#   2021. 09.2       2021. 10 2021. 10.1 2021. 10.2  ... 2022. 04.2  \
# 0      �����  ����Ȱ��������      �Ǿ���      �����  ...      �����
# 1       59.7           62.1        4.2       59.5  ...       60.4
# 2       67.7           70.6        4.6       67.3  ...       68.7
# 3       52.5           54.5        3.7       52.5  ...       52.9
#
#         2022. 05 2022. 05.1 2022. 05.2       2022. 06 2022. 06.1 2022. 06.2  \
# 0  ����Ȱ��������      �Ǿ���      �����  ����Ȱ��������      �Ǿ���      �����
# 1           63.0        3.5       60.8           63.0        3.4       60.8
# 2           71.8        3.7       69.2           71.6        3.3       69.2
# 3           55.0        3.3       53.2           55.2        3.6       53.2
#
#         2022. 07 2022. 07.1 2022. 07.2
# 0  ����Ȱ��������      �Ǿ���      �����
# 1           62.9        3.3       60.9
# 2           71.3        3.4       68.9
# 3           55.4        3.1         53
#
# [4 rows x 37 columns]

# %%
# 옵션 encoding='CP949' 추가
df_work = pd.read_csv('data/고용지표_20221115084415.csv', encoding='CP949')
df_work.head()
# Out:
#    성별(1) 2021. 08 2021. 08.1 2021. 08.2 2021. 09 2021. 09.1 2021. 09.2  \
# 0  성별(1)  경제활동참가율        실업률        고용률  경제활동참가율        실업률        고용률
# 1     합계     61.7        4.0       59.2     61.9        3.6       59.7
# 2     남자     70.0        4.1       67.1     70.3        3.8       67.7
# 3     여자     54.2        3.9       52.1     54.3        3.4       52.5
#
#   2021. 10 2021. 10.1 2021. 10.2  ... 2022. 04.2 2022. 05 2022. 05.1  \
# 0  경제활동참가율        실업률        고용률  ...        고용률  경제활동참가율        실업률
# 1     62.1        4.2       59.5  ...       60.4     63.0        3.5
# 2     70.6        4.6       67.3  ...       68.7     71.8        3.7
# 3     54.5        3.7       52.5  ...       52.9     55.0        3.3
#
#   2022. 05.2 2022. 06 2022. 06.1 2022. 06.2 2022. 07 2022. 07.1 2022. 07.2
# 0        고용률  경제활동참가율        실업률        고용률  경제활동참가율        실업률        고용률
# 1       60.8     63.0        3.4       60.8     62.9        3.3       60.9
# 2       69.2     71.6        3.3       69.2     71.3        3.4       68.9
# 3       53.2     55.2        3.6       53.2     55.4        3.1         53
#
# [4 rows x 37 columns]

# %%
# index, header 지정
df_work =  pd.read_csv('data/고용지표_20221115084415.csv', encoding='CP949', index_col=0, header=[0,1])
df_work.columns
# Out:
# MultiIndex([('2021. 08', '경제활동참가율'),
#             ('2021. 08',     '실업률'),
#             ('2021. 08',     '고용률'),
#             ('2021. 09', '경제활동참가율'),
#             ('2021. 09',     '실업률'),
#             ('2021. 09',     '고용률'),
#             ('2021. 10', '경제활동참가율'),
#             ('2021. 10',     '실업률'),
#             ('2021. 10',     '고용률'),
#             ('2021. 11', '경제활동참가율'),
#             ('2021. 11',     '실업률'),
#             ('2021. 11',     '고용률'),
#             ('2021. 12', '경제활동참가율'),
#             ('2021. 12',     '실업률'),
#             ('2021. 12',     '고용률'),
#             ('2022. 01', '경제활동참가율'),
#             ('2022. 01',     '실업률'),
#             ('2022. 01',     '고용률'),
#             ('2022. 02', '경제활동참가율'),
#             ('2022. 02',     '실업률'),
#             ('2022. 02',     '고용률'),
#             ('2022. 03', '경제활동참가율'),
#             ('2022. 03',     '실업률'),
#             ('2022. 03',     '고용률'),
#             ('2022. 04', '경제활동참가율'),
#             ('2022. 04',     '실업률'),
#             ('2022. 04',     '고용률'),
#             ('2022. 05', '경제활동참가율'),
#             ('2022. 05',     '실업률'),
#             ('2022. 05',     '고용률'),
#             ('2022. 06', '경제활동참가율'),
#             ('2022. 06',     '실업률'),
#             ('2022. 06',     '고용률'),
#             ('2022. 07', '경제활동참가율'),
#             ('2022. 07',     '실업률'),
#             ('2022. 07',     '고용률')],
#            names=['성별(1)', '성별(1)'])

# %% [markdown]
# <br>
#
#
# ### 1.3. Excel 파일 불러오기
#
# `Excel` 파일은 구버전의 **xls**와 새로운 버전의 **xlsx**로 구분하며 추가 라이브러리 `xlrd`와 `openpyxl` 설치 필수
#  이후 pandas의 `read_excel( )`을 사용 가능
#  > pandas 1.3 이전 버전에서는 **xlsx** 파일을 불러올 때 함수 안에 `, engine='openpyxl'`를 추가해야할 수도 있습니다.

# %%
# 무난한 첫번째 시트 데이터 불러오기
sheet1 = pd.read_excel('./data/test.xlsx')
sheet1
# Out:
#    ID  Var1  Var2  Var3
# 0   1    11    45    75
# 1   2    54    32    34
# 2   4    65    43    54

# %%
# 시트 번호 지정하고 2줄 무시하기
sheet2 = pd.read_excel('data/test.xlsx', sheet_name=1, skiprows=2)
sheet2
    ## sheet_name : 시트 이름이나 번호 지정, 번호는 0부터 시작
    ## skiprows   : 무시할 행 수
# Out:
#    이름  나이    키
# 0  민서  20  160
# 1  민준  21  175

# %%
# 첫 행부터 데이터가 시작되는 데이터 불러오기
sheet3 = pd.read_excel('data/test.xlsx', sheet_name=2, header=None)
sheet3
    ## header : 첫 행에 변수이름이 저장되었는지 여부
# Out:
#       0   1
# 0  2015  32
# 1  2016  34
# 2  2017   -

# %%
import pandas as pd

# 첫 행부터 데이터가 시작되는 데이터 불러오면서 변수 이름 지정하기
sheet3 = pd.read_excel('data/test.xlsx', sheet_name=2, header=None, names=['년도','건수'])
sheet3
# Out:
#      년도  건수
# 0  2015  32
# 1  2016  34
# 2  2017   -

# %%
# 결측 저장값 지정하기
sheet3 = pd.read_excel('data/test.xlsx', sheet_name=2, header=None, names=['년도','건수'], na_values='-')
sheet3
    ## NaN : 결측값
# Out:
#      년도    건수
# 0  2015  32.0
# 1  2016  34.0
# 2  2017   NaN

# %% [markdown]
# <br>
#
# ####  [실습] 아래의 사이트에서 관심있는 데이터를 탐색하기
#
# * csv 파일 중 인코딩 관련 에러가 발생할 경우 read_csv( )안에서 `encoding='CP949'` 옵션 추가
# * xlsx의 경우 다운로드한 파일을 열어서 읽기 전용을 해제해야 할 수도 있음
#
#
#
# [공공데이터포털](https://www.data.go.kr/index.do)
#
# [서울 열린데이터 광장](http://data.seoul.go.kr/)
#
# [Dacon](https://dacon.io/)

# %%
df_ebook = pd.read_csv("/Users/jhpark/Downloads/서울특별시 금천구_구립도서관 전자책 보유 목록_20230409.csv", encoding='CP949')
df_ebook["도서명"]
# Out:
# 0                            12월 12일
# 1                            17원 50전
# 2                       1932년의 문단 전망
# 3                              20년 후
# 4                             3월 창작평
#                     ...
# 9167           [오디오북] 한국대표중단편문학 - 빈처
# 9168    [오디오북] 한국대표중단편문학 - B사감과 러브레터
# 9169            [오디오북] 한국대표중단편문학 - 꿈
# 9170          [오디오북] 한국대표중단편문학 - 두포전
# 9171         [오디오북] 한국대표중단편문학 - 배따라기
# Name: 도서명, Length: 9172, dtype: object

# %%
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})

df['A']


filtered = df[ df['B'] <= 5]
#print(filtered)

display(filtered)


#print( len(filtered) )
# Out:
#    A  B
# 0  1  4
# 1  2  5

# %% [markdown]
# ## 2.  DRM 보안 적용된 Excel 파일 불러오기

# %% [markdown]
# ### 2.1. pywin32 활용

# %%
import pandas as pd
import win32com.client as win32
import os 

# Excel 실행
excel=win32.Dispatch('Excel.Application')   

# 경로 지정 및 파일 열기
filepath = os.getcwd() +'/data/test.xlsx'
wb = excel.Workbooks.Open(filepath)

filepath
# Out:
# 'C:\\Users\\jhpark\\Desktop\\7_fastcampus\\Python으로 시작하는 데이터 분석_박종현/data/test.xlsx'

# %%
# Sheet 지정
ws = wb.Worksheets(1) 

# 전체 행, 열 수 확인
nRow = ws.UsedRange.Rows.Count 
nColumn = ws.UsedRange.Columns.Count 

# 불러올 범위 지정
listValue = ws.Range(ws.Cells(1,1) , ws.Cells(nRow,nColumn)).Value
pd.DataFrame(listValue[1:] , columns=listValue[0])
# Out:
#     ID  Var1  Var2  Var3
# 0  1.0  11.0  45.0  75.0
# 1  2.0  54.0  32.0  34.0
# 2  4.0  65.0  43.0  54.0

# %%
# Excel 종료
excel.Quit()

# %% [markdown]
# <br>
#
# 한번에 실행

# %%
import pandas as pd
import win32com.client as win32
import os 

# Excel 실행
excel=win32.Dispatch('Excel.Application')   

# 경로 지정 및 파일 열기
filepath = os.getcwd() +'/data/test.xlsx'
wb = excel.Workbooks.Open(filepath)

# Sheet 지정
ws = wb.Worksheets(1) 

# 전체 행, 열 수 확인
nRow = ws.UsedRange.Rows.Count 
nColumn = ws.UsedRange.Columns.Count 

# 불러올 범위 지정
listValue = ws.Range(ws.Cells(1,1) , ws.Cells(nRow,nColumn)).Value
df_drm = pd.DataFrame(listValue[1:] , columns=listValue[0]) 

excel.Quit()     

df_drm
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 10
#       8 # 경로 지정 및 파일 열기
#       9 filepath = os.getcwd() +'/data/test.xlsx'
# ---> 10 wb = excel.Workbooks.Open(filepath)
#      12 # Sheet 지정
#      13 ws = wb.Worksheets(1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\win32com\client\dynamic.py:639, in CDispatch.__getattr__(self, attr)
#     636     return self._get_good_object_(ret)
#     638 # no where else to look.
# --> 639 raise AttributeError("%s.%s" % (self._username_, attr))
#
# AttributeError: Excel.Application.Workbooks

# %% [markdown]
# <br>
# <br>
#
# ### 2.2. xlwings 라이브러리 활용
#
# + 장점: VBA 연동 가능

# %%
# 라이브러리 설치
# !pip install xlwings

# %%
# 라이브러리 불러오기
import xlwings as xw
import pandas as pd
import os

# %%
# Excel 파일 열기
# filepath = os.getcwd() +'/data/test.xlsx'
book = xw.Book('./data/test.xlsx')

# %%
# Sheet 선택
sheet = book.sheets[0]    

# 전체 데이터 데이터 불러오기
df_drm = sheet.used_range.options(pd.DataFrame, index = False).value
df_drm

# %%
# 특정 부분만 불러오기
sheet = book.sheets[1]    
df_drm = sheet.range("A3:C5").options(pd.DataFrame, index = False).value
df_drm

# %%
# 종료
xw.apps.active.quit()

# %% [markdown]
# #### End of script
