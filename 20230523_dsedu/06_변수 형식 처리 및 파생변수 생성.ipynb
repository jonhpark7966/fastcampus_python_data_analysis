# %% [markdown]
# # 변수 형식 처리 및 파생변수 생성
#
# ### 주요 내용
#
# 1. 변수 수정, 추가 및 제거
# 2. 형식 변환 및 파생변수 생성
# <br>
#
# ### 목표
# 1. 분석 목적에 맞게 변수를 수정하고 파생 변수를 추가할 수 있다.
# 2. 날짜 등 변수 형식을 활용할 수 있다.
#
# <br>
# <hr>
# <br>

# %% [markdown]
# ## 1. 변수(열)의 수정, 추가, 제거
#
# **pandas**의 기본 기능과 메서드를 활용하여 변수를 추가 하거나 수정, 업데이트하거나 제거 가능
# 변수를 선택하듯 **=**을 활용해서 변수를 추가하거나 업데이트 가능

# %% [markdown]
# ### 1.1. 변수 수정 및 추가

# %%
# 라이브러리 불러오기
import pandas as pd


# 예제 만들기 : 딕셔너리를 활용한 DataFrame 생성
df_own = pd.DataFrame({'FIRST' : ['A', 'B', 'C', 'D'],
                       'SECOND': [7,6,5,8], 
                       'THIRD' : pd.date_range('2023-01-01', periods=4, freq='W-SAT')})
df_own

# %%
# 변수 형식 확인
df_own.dtypes

# %%
# 변수이름을 활용한 변수선택
df_own['SECOND']

# %%
# =을 활용한 추가
df_own['FOURTH'] = 0
df_own

# %%
# =을 활용한 업데이트
df_own['FOURTH'] = df_own['SECOND'] + 1
df_own

# %%
# .assign()도 활용 가능
df_own.assign(FOURTH = df_own['SECOND'] + 1)

# %% [markdown]
# <br>
#
# pandas의 *dt.weekday*를 활용하여 날짜시간 변수에서 날짜 요소를 추출
#  * 참고: [dt.weekday](https://pandas.pydata.org/docs/reference/api/pandas.Series.dt.weekday.html)

# %%
# pandas의 dt.weekday 활용
    ## ['THIRD'] 대신 .THIRD 활용가능
df_own['THIRD'].dt.weekday

# %%
df_own['WEEKDAY'] = df_own['THIRD'].dt.weekday
df_own

# %% [markdown]
# <br>
#
# ### 1.2.  변수 제거
#
# *drop()*은 **index**와 **columns**를 활용하여 관측치와 변수를 제거
# `axis=`옵션에 따라 `axis=0`이면 관측치를 제거하거 `axis=1`이면 변수를 제거
#
# `columns=`이라는 옵션을 명시해서 변수를 제거하는 것이 가장 명확하고 실수를 줄일 수 있음

# %%
# drop()을 활용한 관측치/변수 제거
df_own.drop('FOURTH', axis=1)
    # axis = 0 : 관측치
    # axis = 1 : 변수

# %%
# drop()을 활용한 관측치/변수 제거(columns 활용)
df_own.drop(columns=['FOURTH'])

# %%
# drop( ) 실행 후 원본 데이터는 변함이 없음
df_own

# %%
# 원본 데이터의 업데이트
df_own = df_own.drop(columns=['FOURTH'])
df_own

# %%
# 리스트를 활용한 복수 인덱스 제거
df_own.drop([0,3], axis=0)

# %% [markdown]
# <br>
#
# ### 1.3. 변수 이름 변경
#
# 변수이름을 바꾸고 싶을 때는 **DataFrame**의 메서드 *rename()*을 활용
# 이때 `columns=` 옵션을 활용하고 딕셔너리 형식으로 기존변수이름과 새변수이름을 콜론으로 연결

# %%
# rename() 활용 변수 이름 바꾸기 
df_own.rename(columns = {'FIRST':'var1', 'SECOND':'var2'})

# %% [markdown]
# <br>
#
# #### [실습] df_sp를 활용
#
# 1. 'math score', 'reading score', 'writing score'를 합한 변수 'sum'을 **df_sp**에 추가
# 2. 'math score', 'reading score', 'writing score' 중 한과목이라도 40보다 작은지 확인하고 변수 'fail_yn' 추가
# 3. 2.의 'fail_yn'을 활용해서 세 점수 중 하나라도 40점 미만인 학생 선택
# 4. 변수 'sum'의 이름을 'total'로 변경
# 5. 변수 'fail_yn'을 **df_sp**에서 제거하고 원본 데이터 업데이트

# %%
df_sp = pd.read_csv('data/StudentsPerformance.csv')
df_sp.head()

# %%
df_sp["sum"] = df_sp["math score"] + df_sp["writing score"] + df_sp["reading score"]   
df_sp

# %%
# 2. 참고
df_sp["fail_yn"] = (df_sp['math score']<40) | (df_sp['reading score']<40) | (df_sp['writing score']<40)
df_sp

# %%
df_sp[ df_sp["fail_yn"] ]

# %%
df_sp.rename(columns={"sum":"total"})

# %%
df_sp = df_sp.drop(columns=["fail_yn"])

# %% [markdown]
# #### 참고
# 한번에 비교 연산을 하거나 DataFrame의 sum()을 활용 가능

# %%
df_sp.select_dtypes('number') <= 40

# %%
# 하나라도 True인 것 찾기
(df_sp.select_dtypes('number') <= 40).any(axis=1)

# %%
# 변수별로 40점 미만 학생수 계산하기
(df_sp.select_dtypes('number') <= 40).sum(axis=0)

# %%
# 관측치별로 40점 미만 과목수 계산하기
(df_sp.select_dtypes('number') <= 40).sum(axis=1)

# %%
(df_sp.select_dtypes('number') <= 40).sum(axis=1).value_counts()

# %% [markdown]
# <br>
# <hr>
# <br>
#
# ## 2. 변수 형식 변환 및 파생변수 생성
#
# 분석과정에서 변수의 형식을 바꾸거나 기존 변수를 활용한 파생변수 생성 가능
#
#
#
# ### 2.1. 변수 형식의 확인/변환
# **DataFrame**에서는 아래와 같은 형식의 Seires를 활용
#
#
# + float: 실수(소수점을 포함한 숫자)
# + int: 정수(integer)
# + datetime: 날짜시간
# + bool: 불/불린(True 혹은 False)
# + category: 범주형
# + object: 문자형(string) 혹은 그 외
#
# *.dtypes*를 활용하여 변수 형식을 확인
# *.astype()*을 활용해서 변수 형식을 변환

# %%
# 데이터 불러오기
df_ins = pd.read_csv('data/insurance.csv')
df_ins.head()

# %%
# 변수 형식 확인
df_ins.dtypes

# %%
# children을 float으로 변환
df_ins['children'].astype('float')

# %%
# 기존 변수의 형식 업데이트
df_ins['children'] = df_ins['children'].astype('float')
df_ins.head()

# %%
# 복수 변수의 형식 일괄 업데이트
category_vars = ['sex', 'smoker', 'region', "children"]
df_ins[category_vars] = df_ins[category_vars].astype('category')
df_ins.dtypes

# %%
# select_dtypes()의 활용
df_ins.select_dtypes('category')

# %% [markdown]
# <br>
#
# #### [실습] df_pr의 활용
#
# 1. Pulse2(뛴 후)와 Pulse1(뛰기 전)의 차이를 계산하고 'Diff'로 변수 추가하기
# 2. .dtypes로 형식 확인하고 .nunique()로 중복값 제거한 값 개수 확인하기
# 3. 범주형 형식이 적당한 변수 목록 만들기
# 4. 3.의 변수들을 astype()으로 category 형식으로 변환하고 업데이트 하기
# 5. Ran, Smokes, Alcohol별 1.의 Diff의 평균 계산하기

# %%
#df_pr = pd.read_csv('data/PulseRates.csv')
df_pr.head(2)

# %%
df_pr["Diff"] = df_pr["Pulse2"] - df_pr["Pulse1"]

# %%
#df_pr.dtypes
df_pr.nunique()

# %%
category_vars = ['Gender', 'Smokes', 'Alcohol', "Exercise", "Ran", "Year"]
df_pr[category_vars] = df_pr[category_vars].astype('category')
df_pr.dtypes

# %%
df_pr.groupby(["Ran", "Smokes", "Alcohol"], as_index=False)["Diff"].mean()

# %% [markdown]
# <br>
#
# ### 2.2. 수치형 변수의 구간화
#
# 수치형 변수는 *cut()* 이나 *qcut()* 으로 구간화 가능
#
#
# + *cut()*: 등간격 혹은 주어진 구간 경계로 구간화
# + *qcut()*: 등비율로 구간화

# %% [markdown]
# <br>
#
# *cut()*을 활용해서 등간격으로 구간화할 수 있고, `bins=` 옵션에 적절한 구간값을 직접 넣을 수도 있습니다.

# %%
# 등간격으로 구간화하기
pd.cut(df_ins['charges'], bins=10)

# %%
charges_breaks = [0, 5000, 10000, 20000, 99999999999999]

# %%
pd.cut(df_ins['charges'], bins=charges_breaks, right=False, labels=['4','3','2','1'])

# %%
# cut()을 활용한 10등급화
df_ins['charges_grp'] = pd.cut(df_ins['charges'], bins=10, labels=range(10))
df_ins

# %%
# 등구간의 관측치 불균형 문제
df_ins['charges_grp'].value_counts()

# %%
# qcut()을 활용한 등비율 구간화
df_ins['charges_grp2'] = pd.qcut(df_ins['charges'], q=10, labels=range(1,11))
df_ins

# %%
df_ins['charges_grp2'].value_counts()

# %% [markdown]
# <br>
#
# #### [실습] 데이터 df_sp 활용
#
# 1. cut()으로 'reading score'를 20점 단위로 5개 그룹 변수 추가
# 2. cut()으로 'reading score'를 등간격(구간 길이 동일)으로 5개 그룹 변수 추가
# 3. qcut()으로 'readiong score'를 등비율로 5 등급화
# 4. crosstab()을 활용해서 'parental level of education'과 3.의 그룹 변수로 교차표 생성/열지도 시각화

# %%
df_sp.head()

# %%
score_breaks = [0,20,40,60,80,100]
df_sp["r_grp1"] = pd.cut(df_sp["reading score"], bins=score_breaks, labels=range(1,6))

# %%
df_sp["r_grp2"] = pd.cut(df_sp["reading score"], bins=5, labels=range(1,6))

# %%
df_sp["r_grp3"] = pd.qcut(df_sp["reading score"], q=5, labels = range(1,6))

# %%
import seaborn as sns

# %%
sns.boxplot(data=df_sp, y="reading score", x="parental level of education")

# %%
df_tab = pd.crosstab(df_sp["parental level of education"], df_sp["r_grp3"], normalize="index")
sns.heatmap(df_tab, cmap="YlGnBu", annot=True)

# %% [markdown]
# ### 2.3. 날짜시간 변수 활용
#
# 날짜시간 변수에서 요소를 추출할 수 있고, 날짜시간별로 집계된 데이터로 시각화 가능

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

# %%
df_subway = pd.read_csv('data/서울교통공사_역별일별승하차인원정보_20220731.csv')
df_subway.head(3)

# %%
# to_datetime()을 활용한 형식 변환
df_subway['호선'] = df_subway['호선'].astype('category')
df_subway['날짜'] = pd.to_datetime(df_subway['날짜'])
df_subway.dtypes

# %%
# 요일 변수 생성
df_subway['요일'] = df_subway['날짜'].dt.weekday
df_subway

# %%
# 월 변수 생성
df_subway['월'] = df_subway['날짜'].dt.month
df_subway

# %%
# 날짜별 집계값의 생성
agg = df_subway.groupby(['날짜','호선'], as_index=False)['이용객수'].sum()
agg

# %%
# 시계열 데이터의 시각화 
sns.lineplot(data=agg, 
             x='날짜',
             y='이용객수',
             hue='호선')

# %% [markdown]
# #### [실습] df_accident를 활용하여 7, 8월 새벽 1~5시 사고 건수 계산

# %%
df_accident = pd.read_csv('data/도로교통공단_사망 교통사고 정보_20211231_utf8.csv')
df_accident.head(3)

# %%
df_accident['발생년월일시'] = pd.to_datetime(df_accident['발생년월일시'])
df_accident['요일'] = df_accident['발생년월일시'].dt.weekday
df_accident['월'] = df_accident['발생년월일시'].dt.month
df_accident['시'] = df_accident['발생년월일시'].dt.hour
df_accident[['발생년월일시', '요일', '월','시']]
# Out:
#                   발생년월일시  요일   월   시
# 0    2021-01-01 03:00:00   4   1   3
# 1    2021-01-01 09:00:00   4   1   9
# 2    2021-01-01 15:00:00   4   1  15
# 3    2021-01-01 19:00:00   4   1  19
# 4    2021-01-01 21:00:00   4   1  21
# ...                  ...  ..  ..  ..
# 2811 2021-12-31 16:00:00   4  12  16
# 2812 2021-12-31 17:00:00   4  12  17
# 2813 2021-12-31 18:00:00   4  12  18
# 2814 2021-12-31 19:00:00   4  12  19
# 2815 2021-12-31 21:00:00   4  12  21
#
# [2816 rows x 4 columns]

# %%
df_accident[  df_accident["월"].between(7,8) & df_accident["시"].between(1,5) ].shape[0]
# Out:
# 74

# %%
df_accident[  (df_accident["월"]==10) & (df_accident["시"]==18) ]
# Out:
#        발생년              발생년월일시 주야  요일  사망자수  부상자수  중상자수  경상자수  부상신고자수 발생지시도  \
# 1979  2021 2021-10-01 18:00:00  야   4     1     0     0     0       0    경북
# 1980  2021 2021-10-01 18:00:00  야   4     1     0     0     0       0    경북
# 1989  2021 2021-10-02 18:00:00  야   5     1     0     0     0       0    충남
# 2031  2021 2021-10-07 18:00:00  야   3     1     0     0     0       0    경기
# 2032  2021 2021-10-07 18:00:00  야   3     1     0     0     0       0    경기
# 2054  2021 2021-10-09 18:00:00  야   5     1     0     0     0       0    충북
# 2064  2021 2021-10-10 18:00:00  야   6     1     2     0     2       0    대구
# 2091  2021 2021-10-13 18:00:00  야   2     1     1     0     1       0    경북
# 2104  2021 2021-10-14 18:00:00  야   3     1     0     0     0       0    충남
# 2105  2021 2021-10-14 18:00:00  야   3     1     1     1     0       0    충남
# 2106  2021 2021-10-14 18:00:00  야   3     1     0     0     0       0    전남
# 2107  2021 2021-10-14 18:00:00  야   3     1     0     0     0       0    경북
# 2108  2021 2021-10-14 18:00:00  야   3     1     0     0     0       0    세종
# 2118  2021 2021-10-16 18:00:00  야   5     1     0     0     0       0    충남
# 2136  2021 2021-10-18 18:00:00  야   0     1     0     0     0       0    서울
# 2137  2021 2021-10-18 18:00:00  야   0     1     0     0     0       0    전북
# 2143  2021 2021-10-19 18:00:00  야   1     1     0     0     0       0    충남
# 2144  2021 2021-10-19 18:00:00  야   1     1     0     0     0       0    경남
# 2169  2021 2021-10-22 18:00:00  야   4     1     0     0     0       0    서울
# 2170  2021 2021-10-22 18:00:00  야   4     1     0     0     0       0    전북
# 2178  2021 2021-10-23 18:00:00  야   5     1     0     0     0       0    충북
# 2179  2021 2021-10-23 18:00:00  야   5     1     0     0     0       0    경남
# 2191  2021 2021-10-24 18:00:00  야   6     1     0     0     0       0    전남
# 2192  2021 2021-10-24 18:00:00  야   6     1     0     0     0       0    경남
# 2201  2021 2021-10-25 18:00:00  야   0     1     1     0     1       0    인천
# 2202  2021 2021-10-25 18:00:00  야   0     1     0     0     0       0    대전
# 2214  2021 2021-10-26 18:00:00  야   1     1     0     0     0       0    경북
# 2230  2021 2021-10-27 18:00:00  야   2     1     0     0     0       0    경북
# 2247  2021 2021-10-28 18:00:00  야   3     1     0     0     0       0    경남
# 2248  2021 2021-10-28 18:00:00  야   3     1     0     0     0       0    경남
# 2249  2021 2021-10-28 18:00:00  야   3     1     0     0     0       0    울산
# 2265  2021 2021-10-29 18:00:00  야   4     1     0     0     0       0    대구
# 2281  2021 2021-10-31 18:00:00  야   6     1     0     0     0       0    경남
#
#       ... 도로형태_대분류      도로형태    가해자_당사자종별 피해자_당사자종별 발생위치X(UTMK) 발생위치Y(UTMK)  \
# 1979  ...      단일로     기타단일로          승용차       농기계   1101227.0   1814285.0
# 1980  ...      단일로     기타단일로          승용차       보행자   1169700.0   1894276.0
# 1989  ...      교차로  교차로횡단보도내          승용차       보행자    920464.0   1815420.0
# 2031  ...      교차로     교차로부근          승용차       이륜차    960267.0   1908002.0
# 2032  ...      단일로     기타단일로          승용차       보행자    974564.0   1954211.0
# 2054  ...      단일로     기타단일로  사륜오토바이(ATV)        없음   1041234.0   1896565.0
# 2064  ...      교차로      교차로내          승용차       이륜차   1095237.0   1764291.0
# 2091  ...      단일로     기타단일로          이륜차       승용차   1054311.0   1800845.0
# 2104  ...      단일로     기타단일로          승용차       보행자    921486.0   1836526.0
# 2105  ...      단일로     기타단일로          화물차       농기계    936617.0   1866275.0
# 2106  ...      단일로     기타단일로          화물차       보행자    896402.0   1662310.0
# 2107  ...      단일로     기타단일로          승용차       보행자   1167866.0   1823949.0
# 2108  ...      단일로       교량위          이륜차        없음    975051.0   1832219.0
# 2118  ...      단일로     기타단일로          승용차       보행자    917653.0   1868578.0
# 2136  ...      단일로     기타단일로          이륜차        없음    959973.0   1956316.0
# 2137  ...      단일로     기타단일로          승용차       보행자    954568.5   1780997.2
# 2143  ...      단일로     기타단일로          승용차       보행자    924195.0   1879071.0
# 2144  ...      단일로     기타단일로          승용차       보행자   1060923.0   1683664.0
# 2169  ...      교차로     교차로부근          승용차       보행자    941249.0   1946473.0
# 2170  ...      단일로     기타단일로          승합차       보행자    929750.0   1776222.1
# 2178  ...      단일로     기타단일로          승용차       이륜차   1002263.0   1868814.0
# 2179  ...      단일로     기타단일로          승용차       보행자   1074886.0   1664604.0
# 2191  ...       기타        기타          화물차       보행자    910018.0   1652804.0
# 2192  ...      교차로      교차로내          승용차       보행자   1112684.0   1722360.0
# 2201  ...      교차로     교차로부근          화물차       승용차    924771.0   1946287.0
# 2202  ...      단일로     기타단일로          승용차       보행자    995443.0   1816166.0
# 2214  ...      단일로     기타단일로          화물차       보행자   1054123.0   1792796.0
# 2230  ...      교차로     교차로부근          화물차       보행자   1096892.0   1820475.0
# 2247  ...      교차로     교차로부근          승용차       보행자   1092019.0   1679303.0
# 2248  ...      교차로      교차로내          승용차       보행자   1084700.0   1706212.0
# 2249  ...      교차로  교차로횡단보도내          승합차       보행자   1164606.0   1727572.0
# 2265  ...      단일로     기타단일로          승용차       보행자   1103403.0   1754435.0
# 2281  ...      단일로     기타단일로          승용차       보행자   1077116.0   1661448.0
#
#               경도         위도   월   시
# 1979  128.627712  36.320612  10  18
# 1980  129.407949  37.031700  10  18
# 1989  126.613789  36.332878  10  18
# 2031  127.052445  37.169928  10  18
# 2032  127.211896  37.586942  10  18
# 2054  127.963832  37.066770  10  18
# 2064  128.554950  35.870564  10  18
# 2091  128.104152  36.203238  10  18
# 2104  126.623038  36.523217  10  18
# 2105  126.789571  36.792505  10  18
# 2106  126.365411  34.950352  10  18
# 2107  129.371898  36.398384  10  18
# 2108  127.221458  36.487287  10  18
# 2118  126.576786  36.811804  10  18
# 2136  127.046518  37.605396  10  18
# 2137  126.995765  36.024759  10  18
# 2143  126.649074  36.906931  10  18
# 2144  128.168825  35.146363  10  18
# 2169  126.835186  37.515676  10  18
# 2170  126.720752  35.980237  10  18
# 2178  127.525373  36.817512  10  18
# 2179  128.320380  34.973567  10  18
# 2191  126.515534  34.865945  10  18
# 2192  128.742301  35.490733  10  18
# 2201  126.648760  37.512803  10  18
# 2202  127.449218  36.342879  10  18
# 2214  128.101506  36.130685  10  18
# 2230  128.580197  36.376853  10  18
# 2247  128.509679  35.104680  10  18
# 2248  128.432152  35.347931  10  18
# 2249  129.315564  35.530455  10  18
# 2265  128.644115  35.780889  10  18
# 2281  128.344516  34.944943  10  18
#
# [33 rows x 25 columns]

# %%
df_pivot = df_accident.pivot_table(index="월", columns="시", values="사망자수", aggfunc="sum")
sns.heatmap(df_pivot, annot=True)
# Out:
# <Axes: xlabel='시', ylabel='월'>

# %%
df_accident.groupby("사고유형", as_index=False)["사망자수"].mean()
# Out:
#           사고유형      사망자수
# 0        공작물충돌  1.042945
# 1           기타  1.023876
# 2   길가장자리구역통행중  1.100000
# 3      도로이탈 기타  1.058824
# 4      도로이탈 추락  1.089552
# 5        보도통행중  1.000000
# 6           전도  1.012346
# 7           전복  1.200000
# 8         정면충돌  1.073298
# 9    주/정차차량 충돌  1.000000
# 10       차도통행중  1.000000
# 11          추돌  1.067606
# 12        측면충돌  1.025381
# 13         횡단중  1.009070
# 14       후진중충돌  1.000000

# %%
for val in ["사망자수","부상자수","중상자수","경상자수"]:
    df_pivot = df_accident.pivot_table(index="월", columns="시", values=val, aggfunc="sum")
    sns.heatmap(df_pivot)
    plt.show()

# %% [markdown]
# #### End of script
