# %% [markdown]
# # 슈카월드 컨텐츠를 기반으로 채팅하기

# %% [markdown]
# ## Semantic Searching
#   - 데이터를 로드합니다.
#   - 질문의 Embedding 을 계산합니다.
#   - 계산된 Embedding 과 유사한 결과들을 탐색합니다.
#   - (참조) https://platform.openai.com/docs/guides/embeddings/what-are-embeddings

# %%
# !pip install tiktoken
# !pip install openai -U
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: tiktoken in c:\users\jhpark\anaconda3\lib\site-packages (0.5.1)
# Requirement already satisfied: requests>=2.26.0 in c:\users\jhpark\anaconda3\lib\site-packages (from tiktoken) (2.28.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\jhpark\anaconda3\lib\site-packages (from tiktoken) (2022.7.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\jhpark\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jhpark\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jhpark\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jhpark\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken) (2022.12.7)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\jhpark\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\jhpark\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\jhpark\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\jhpark\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\jhpark\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\jhpark\anaconda3\lib\site-packages)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: openai in c:\users\jhpark\anaconda3\lib\site-packages (1.3.5)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\jhpark\anaconda3\lib\site-packages (from openai) (2.5.2)
# Requirement already satisfied: anyio<4,>=3.5.0 in c:\users\jhpark\anaconda3\lib\site-packages (from openai) (3.5.0)
# Requirement already satisfied: tqdm>4 in c:\users\jhpark\anaconda3\lib\site-packages (from openai) (4.64.1)
# Requirement already satisfied: typing-extensions<5,>=4.5 in c:\users\jhpark\anaconda3\lib\site-packages (from openai) (4.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\jhpark\anaconda3\lib\site-packages (from openai) (0.25.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\jhpark\anaconda3\lib\site-packages (from openai) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\jhpark\anaconda3\lib\site-packages (from anyio<4,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: idna>=2.8 in c:\users\jhpark\anaconda3\lib\site-packages (from anyio<4,>=3.5.0->openai) (3.4)
# Requirement already satisfied: httpcore in c:\users\jhpark\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: certifi in c:\users\jhpark\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (2022.12.7)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\jhpark\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in c:\users\jhpark\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.14.5)
# Requirement already satisfied: colorama in c:\users\jhpark\anaconda3\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\jhpark\anaconda3\lib\site-packages (from httpcore->httpx<1,>=0.23.0->openai) (0.14.0)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\jhpark\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\jhpark\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\jhpark\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\jhpark\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\jhpark\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\jhpark\anaconda3\lib\site-packages)

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ---------------
# absl-py                       1.4.0
# aiohttp                       3.8.5
# aiosignal                     1.3.1
# alabaster                     0.7.12
# anaconda-client               1.11.2
# anaconda-navigator            2.4.0
# anaconda-project              0.11.1
# annotated-types               0.6.0
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# array-record                  0.4.1
# arrow                         1.2.3
# astroid                       2.14.2
# astropy                       5.1
# asttokens                     2.0.5
# astunparse                    1.6.3
# async-timeout                 4.0.3
# atomicwrites                  1.4.0
# attrs                         22.1.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.11.0
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# basemap                       1.3.8
# basemap-data                  1.3.2
# bcrypt                        3.2.0
# beautifulsoup4                4.11.1
# binaryornot                   0.4.4
# black                         22.6.0
# bleach                        4.1.0
# bokeh                         2.4.3
# boltons                       23.0.0
# Bottleneck                    1.3.5
# breadability                  0.1.20
# brotlipy                      0.7.0
# cachetools                    5.3.1
# certifi                       2022.12.7
# cffi                          1.15.1
# chardet                       4.0.0
# charset-normalizer            2.0.4
# click                         8.0.4
# cloudpickle                   2.0.0
# clyent                        1.2.2
# colorama                      0.4.6
# colorcet                      3.0.1
# comm                          0.1.2
# comtypes                      1.2.0
# conda                         23.3.1
# conda-build                   3.24.0
# conda-content-trust           0.1.3
# conda-pack                    0.6.0
# conda-package-handling        2.0.2
# conda_package_streaming       0.7.0
# conda-repo-cli                1.0.41
# conda-token                   0.4.0
# conda-verify                  3.4.2
# constantly                    15.1.0
# contourpy                     1.1.0
# cookiecutter                  1.7.3
# cryptography                  39.0.1
# cssselect                     1.1.0
# cycler                        0.11.0
# cytoolz                       0.12.0
# daal4py                       2023.0.2
# dask                          2022.7.0
# datashader                    0.14.4
# datashape                     0.5.4
# debugpy                       1.5.1
# decorator                     5.1.1
# defusedxml                    0.7.1
# diff-match-patch              20200713
# dill                          0.3.6
# distributed                   2022.7.0
# distro                        1.8.0
# dm-tree                       0.1.8
# docopt                        0.6.2
# docstring-to-markdown         0.11
# docutils                      0.18.1
# entrypoints                   0.4
# et-xmlfile                    1.1.0
# etils                         1.5.0
# executing                     0.8.3
# fastjsonschema                2.16.2
# feedfinder2                   0.0.4
# feedparser                    6.0.10
# filelock                      3.9.0
# flake8                        6.0.0
# Flask                         2.2.2
# flatbuffers                   23.5.26
# flit_core                     3.6.0
# fonttools                     4.42.0
# frozenlist                    1.4.0
# fsspec                        2022.11.0
# future                        0.18.3
# gast                          0.4.0
# gdown                         4.7.1
# gensim                        4.3.0
# glob2                         0.7
# google-api-core               2.11.1
# google-api-python-client      2.101.0
# google-auth                   2.22.0
# google-auth-httplib2          0.1.1
# google-auth-oauthlib          1.0.0
# google-cloud-texttospeech     2.14.1
# google-pasta                  0.2.0
# googleapis-common-protos      1.59.1
# greenlet                      2.0.1
# grpcio                        1.56.0
# grpcio-status                 1.56.0
# gTTS                          2.3.2
# h11                           0.14.0
# h5py                          3.7.0
# HeapDict                      1.0.1
# holoviews                     1.15.4
# httpcore                      1.0.2
# httplib2                      0.22.0
# httpx                         0.25.1
# huggingface-hub               0.10.1
# hvplot                        0.8.2
# hyperlink                     21.0.0
# idna                          3.4
# imagecodecs                   2021.8.26
# imageio                       2.26.0
# imagesize                     1.4.1
# imbalanced-learn              0.10.1
# importlib-metadata            4.11.3
# importlib-resources           6.1.0
# incremental                   21.3.0
# inflection                    0.5.1
# iniconfig                     1.1.1
# intake                        0.6.7
# intervaltree                  3.1.0
# ipykernel                     6.19.2
# ipython                       8.10.0
# ipython-genutils              0.2.0
# ipywidgets                    7.6.5
# isort                         5.9.3
# itemadapter                   0.3.0
# itemloaders                   1.0.4
# itsdangerous                  2.0.1
# jedi                          0.18.1
# jellyfish                     0.9.0
# jieba3k                       0.35.1
# Jinja2                        3.1.2
# jinja2-time                   0.2.0
# jmespath                      0.10.0
# joblib                        1.1.1
# json5                         0.9.6
# jsonpatch                     1.32
# jsonpointer                   2.1
# jsonschema                    4.17.3
# jupyter                       1.0.0
# jupyter_client                7.3.4
# jupyter-console               6.6.2
# jupyter_core                  5.2.0
# jupyter-server                1.23.4
# jupyterlab                    3.5.3
# jupyterlab-pygments           0.1.2
# jupyterlab_server             2.19.0
# jupyterlab-widgets            1.0.0
# keras                         2.15.0
# keras-core                    0.1.7
# keras-cv                      0.6.4
# keyring                       23.4.0
# kiwisolver                    1.4.4
# lazy-object-proxy             1.6.0
# libarchive-c                  2.9
# libclang                      16.0.6
# llvmlite                      0.39.1
# locket                        1.0.0
# lxml                          4.9.1
# lz4                           3.1.3
# Markdown                      3.4.1
# markdown-it-py                3.0.0
# MarkupSafe                    2.1.1
# matplotlib                    3.7.2
# matplotlib-inline             0.1.6
# mccabe                        0.7.0
# mdurl                         0.1.2
# menuinst                      1.4.19
# mistune                       0.8.4
# mkl-fft                       1.3.1
# mkl-random                    1.2.2
# mkl-service                   2.4.0
# ml-dtypes                     0.2.0
# mock                          4.0.3
# mpmath                        1.2.1
# msgpack                       1.0.3
# multidict                     6.0.4
# multipledispatch              0.6.0
# munkres                       1.1.4
# mypy-extensions               0.4.3
# namex                         0.0.7
# navigator-updater             0.3.0
# nbclassic                     0.5.2
# nbclient                      0.5.13
# nbconvert                     6.5.4
# nbformat                      5.7.0
# nest-asyncio                  1.5.6
# networkx                      2.8.4
# newspaper3k                   0.2.8
# nltk                          3.7
# notebook                      6.5.2
# notebook_shim                 0.2.2
# numba                         0.56.4
# numexpr                       2.8.4
# numpy                         1.24.3
# numpydoc                      1.5.0
# nvidia-pyindex                1.0.9
# oauthlib                      3.2.2
# openai                        1.3.5
# openpyxl                      3.0.10
# opt-einsum                    3.3.0
# packaging                     23.1
# pandas                        1.5.3
# pandoc                        2.3
# pandocfilters                 1.5.0
# panel                         0.14.3
# param                         1.12.3
# paramiko                      2.8.1
# parsel                        1.6.0
# parso                         0.8.3
# partd                         1.2.0
# pathlib                       1.0.1
# pathspec                      0.10.3
# patsy                         0.5.3
# pep8                          1.7.1
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        10.0.0
# pip                           22.3.1
# pkginfo                       1.9.6
# platformdirs                  2.5.2
# plotly                        5.9.0
# pluggy                        1.0.0
# plumbum                       1.8.2
# ply                           3.11
# pooch                         1.4.0
# poyo                          0.5.0
# prometheus-client             0.14.1
# promise                       2.3
# prompt-toolkit                3.0.36
# Protego                       0.1.16
# proto-plus                    1.22.3
# protobuf                      3.20.3
# psutil                        5.9.0
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# py                            1.11.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycodestyle                   2.10.0
# pycosat                       0.6.4
# pycountry                     22.3.5
# pycparser                     2.21
# pyct                          0.5.0
# pycurl                        7.45.1
# pydantic                      2.5.2
# pydantic_core                 2.14.5
# PyDispatcher                  2.0.5
# pydocstyle                    6.3.0
# pydot                         1.4.2
# pyee                          8.2.2
# pyerfa                        2.0.0
# pyflakes                      3.0.1
# Pygments                      2.16.1
# PyHamcrest                    2.0.2
# PyJWT                         2.4.0
# pylint                        2.16.2
# pylint-venv                   2.3.0
# pyls-spyder                   0.4.0
# PyNaCl                        1.5.0
# pyodbc                        4.0.34
# pyOpenSSL                     23.0.0
# pyparsing                     3.0.9
# pypiwin32                     223
# pyppeteer                     1.0.2
# pyproj                        3.6.0
# PyQt5                         5.15.7
# PyQt5-sip                     12.11.0
# PyQtWebEngine                 5.15.4
# pyrsistent                    0.18.0
# pyshp                         2.3.1
# PySocks                       1.7.1
# pytest                        7.1.2
# python-dateutil               2.8.2
# python-lsp-black              1.2.1
# python-lsp-jsonrpc            1.0.0
# python-lsp-server             1.7.1
# python-slugify                5.0.2
# python-snappy                 0.6.1
# pytoolconfig                  1.2.5
# pyttsx3                       2.90
# pytz                          2022.7
# pyviz-comms                   2.0.2
# PyWavelets                    1.4.1
# pywin32                       305.1
# pywin32-ctypes                0.2.0
# pywinpty                      2.0.10
# PyYAML                        6.0
# pyzmq                         23.2.0
# QDarkStyle                    3.0.2
# qstylizer                     0.2.2
# QtAwesome                     1.2.2
# qtconsole                     5.4.0
# QtPy                          2.2.0
# queuelib                      1.5.0
# regex                         2022.7.9
# requests                      2.28.1
# requests-file                 1.5.1
# requests-oauthlib             1.3.1
# requests-toolbelt             0.9.1
# rich                          13.5.3
# rope                          1.7.0
# rsa                           4.9
# Rtree                         1.0.1
# ruamel.yaml                   0.17.21
# ruamel.yaml.clib              0.2.6
# ruamel-yaml-conda             0.17.21
# scikit-image                  0.19.3
# scikit-learn                  1.2.1
# scikit-learn-intelex          20230228.214818
# scipy                         1.10.0
# Scrapy                        2.8.0
# seaborn                       0.12.2
# Send2Trash                    1.8.0
# service-identity              18.1.0
# setuptools                    65.6.3
# sgmllib3k                     1.0.0
# sip                           6.6.2
# six                           1.16.0
# smart-open                    5.2.1
# sniffio                       1.2.0
# snowballstemmer               2.2.0
# sortedcontainers              2.4.0
# soupsieve                     2.3.2.post1
# Sphinx                        5.0.2
# sphinxcontrib-applehelp       1.0.2
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.0
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# spyder                        5.4.1
# spyder-kernels                2.4.1
# SQLAlchemy                    1.4.39
# stack-data                    0.2.0
# statsmodels                   0.13.5
# sumy                          0.11.0
# sympy                         1.11.1
# tables                        3.7.0
# tabulate                      0.8.10
# TBB                           0.2
# tblib                         1.7.0
# tenacity                      8.0.1
# tensorboard                   2.15.1
# tensorboard-data-server       0.7.1
# tensorflow                    2.14.0
# tensorflow-datasets           4.9.3
# tensorflow-estimator          2.15.0
# tensorflow-hub                0.14.0
# tensorflow-intel              2.15.0
# tensorflow-io-gcs-filesystem  0.31.0
# tensorflow-metadata           1.14.0
# termcolor                     2.3.0
# terminado                     0.17.1
# text-unidecode                1.3
# textdistance                  4.2.1
# threadpoolctl                 2.2.0
# three-merge                   0.1.1
# tifffile                      2021.7.2
# tiktoken                      0.5.1
# tinycss2                      1.2.1
# tinysegmenter                 0.3
# tldextract                    3.2.0
# tokenizers                    0.11.4
# toml                          0.10.2
# tomli                         2.0.1
# tomlkit                       0.11.1
# toolz                         0.12.0
# torch                         1.12.1
# tornado                       6.1
# tqdm                          4.64.1
# traitlets                     5.7.1
# transformers                  4.24.0
# Twisted                       22.2.0
# twisted-iocpsupport           1.0.2
# typing_extensions             4.8.0
# ujson                         5.4.0
# Unidecode                     1.2.0
# uritemplate                   4.1.1
# urllib3                       1.26.14
# w3lib                         1.21.0
# watchdog                      2.1.6
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              0.58.0
# websockets                    10.4
# Werkzeug                      2.2.2
# whatthepatch                  1.0.2
# wheel                         0.38.4
# widgetsnbextension            3.5.2
# win-inet-pton                 1.1.0
# wincertstore                  0.2
# wrapt                         1.14.1
# xarray                        2022.11.0
# xlwings                       0.29.1
# yapf                          0.31.0
# yarl                          1.9.2
# youtube-transcript-api        0.6.1
# zict                          2.1.0
# zipp                          3.11.0
# zope.interface                5.4.0
# zstandard                     0.19.0
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\jhpark\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\jhpark\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\jhpark\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\jhpark\anaconda3\lib\site-packages)

# %%
import numpy as np
import pandas as pd
import openai
import tiktoken

# %%
openai.api_key = "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"

# %%
datafile_path = "./data/shuka_embeddings.csv"

df = pd.read_csv(datafile_path)
df["embedding"] = df.embedding.apply(eval).apply(np.array)
df
# Out:
#      Unnamed: 0           id                                       title  \
# 0             0  ivfBP9XempU                          제주도 보다 큰 미국 농장의 위엄
# 1             1  JhcYEf319YA                          가슴 아픈 이마트 시가총액 2조원
# 2             2  kJBsrOS3rzo                특검, 특검, 특검, 미 대선을 흔드는 사법 리스크
# 1    이마트 시가총액이 이 씨라는 주제로 시작해 볼 텐데 이 씨는 1위 유통업체 중에서 ...
# 2    미국 메카시 하원의장이 바이든 대통령을 탄핵하기 위해 바이든 탄핵 조사를 실시했다 ...
# 3    역대 1위라고 불리는 3천억 횡령 사건이 대한민국에서 또 발생했다 은행에서 발생한 ...
# 4    G20 정상회의는 미국, 러시아, 한국, 중국, 일본, 영국, 프랑스, 독일, 브라...
# ..                                                 ...
# 488  도지 코인이 급등하면서 시청 50조 를 돌파했다 시청 50조 를 돌파한 것은 미국의...
# 489  우리 젊은 20대 30대 생각을 들어 보면 뉴스를 보거나 신문을 보더라도 세대 갈등...
# 490  러시아의 푸틴 대통령이 선거법 개정안이 통과됐고 헌법 개정을 통해 선거법 개정안이 ...
# 491  역사에 남을 만우절 장난이 발생했는데 우리의 이름은 볼 치바 긴 이라고 공식 홈페이...
# 492  성평등 얘기 젠더 이슈가 우리 사회를 완전히 잡아먹고 있는데 남녀 갈 때는 우리 사...
#
#                                               combined  \
# 0    Title: 제주도 보다 큰 미국 농장의 위엄; Content: 미국의 1조 농장이...
# 1    Title: 가슴 아픈 이마트 시가총액 2조원; Content: 이마트 시가총액이 ...
# 2    Title: 특검, 특검, 특검, 미 대선을 흔드는 사법 리스크; Content: ...
# 3    Title: 역대 최대 금액, 3천억 원 횡령 발생; Content: 역대 1위라고...
# 4    Title: 2030년 세계 GDP 3위, 인도의 야망; Content: G20 정...
# ..                                                 ...
# 488  Title: 장난으로 만든 도지코인, 초유의 시총 50조원 돌파; Content: ...
# 489  Title: 힘든 청춘들, 서로 사랑하기를 응원합니다.; Content: 우리 젊은...
# 490  Title: 푸틴 종신집권의 꿈과 압도적인 러시아 청년 지지율 86%; Conten...
# 491  Title: &#39;볼츠바겐&#39;, 역사에 남을 만우절 장난의 뜨거운 후폭풍;...
# 492  Title: 심각해져가는 남녀갈등에 경제학적 팃포탯(Tit for Tat) 전략을 ...
#
#                                              embedding
# 0    [0.006102622990667008, -0.014742583866790107, ...
# 1    [-0.0011725858647948365, -0.003846474179674443...
# 2    [-0.00939853975668415, -0.009666877079379067, ...
# 3    [-0.011554287368376432, -0.011808374510157043,...
# 4    [0.008519676672105264, -0.02860960231180057, 0...
# ..                                                 ...
# 488  [-0.0047661971330641125, -0.00631537639465818,...
# 489  [-0.005508284529859694, -0.013253675914015453,...
# 490  [0.010583974648036551, -0.006855907997017619, ...
# 491  [-0.02736300506219729, -0.027753711685491515, ...
# 492  [-0.03028114028516958, -0.035637537567681385, ...
#
# [493 rows x 9 columns]

# %%
import numpy as np
from numpy import dot
from numpy.linalg import norm

def cos_sim(A, B):
  return dot(A, B)/(norm(A)*norm(B))

from openai import OpenAI
client = OpenAI(api_key=openai.api_key,)

def get_embedding(text, model="text-embedding-ada-002"):
   text = text.replace("\n", " ")
   return client.embeddings.create(input = [text], model=model).data[0].embedding

# 연관된 영상을 검색합니다.
def search_video(df, product_description, n=3, pprint=True):
    product_embedding = get_embedding(
        product_description,
    )
    df["similarity"] = df.embedding.apply(lambda x: cos_sim(x, product_embedding))

    results = (
        df.sort_values("similarity", ascending=False)
        .head(n)
    )

    return results

# %%
# 하고 싶은 말을 입력하고, 비슷한 결과들을 열람합니다.

results = search_video(df, "러시아와 우크라이나의 전쟁은 어떻게 되어가고 있나요?", n=5)
results
# Out:
#      Unnamed: 0           id                          title  \
# 255         257  0q2U1Dgmpgg               세계가 놀란 우크라이나의 반격
# 133         133  bO96Pvd8jx0  한국식 휴전 모델? 교착상태에 빠지는 우크라이나 전쟁
# 243         245  VL696LKF5d4           아 제발.. 고조되는 러시아발 핵위협
# 283         288  dtlA94a3TSI   형제여.. 폴란드, 대한민국 무기 약 20조원 구매
# 101         101  xX8ZwBTAwxM           나으리 우리는 수출만 했을 뿐입니다.
#
#               publishTime                                        description  \
# 255  2022-09-13T10:15:38Z  0:00 ~ 5:05 예상치 못한 우크라이나의 반격 5:05 ~ 14:20 미국의 ...
# 133  2023-03-08T11:57:19Z  0:00 ~ 7:58 바이든 대통령 깜짝 방문 7:58 ~ 14:09 부산스러운 미...
# 243  2022-10-05T10:26:57Z  어렵고 딱딱한 경제,시사,금융 이야기를 쉽고 유쾌하게 풀어내는 경제/시사/이슈/잡썰...
# 283  2022-08-01T11:22:16Z  0:00 ~ 11:29 세계 2차 대전에 책임이 있는 폴란드? 11:29 ~ 19:...
# 101  2023-04-24T11:12:14Z  0:00 ~ 12:14 러시아가 한국의 무기 제공(?)에 대해 위협했다. 12:14...
#
#                                             transcript  \
# 255  우크라이나의 반격이 러시아와 다른 모든 국가를 놀라게 했다 지금 서구 대표적인 언론...
# 133  자 얼마 전에 무슨 날이었냐? 바로 어느새 우크라이나 전쟁 1주기였습니다 2022년...
# 243  푸틴이 우크라이나의 영토합병을 서명했습니다 서명하면서 연설도 했죠 뭐라고했냐 이것은...
# 283  폴란드가 형제의 나라로 급부상하고 있다 [박수] 야야~ 언제 형제가 되었어 야~ 몰...
# 101  러시아가 한국을 위협한 얘기를 뉴스식으로 빨리 진행해 보도록 하겠습니다 다 보셨죠?...
#
#                                             summarized  \
# 255  러시아가 쇼킹상태라고 하는 우크라이나의 반격 때문에 어떤 일이 있었는지 살펴보도록 ...
# 133  우크라이나 전쟁 1주기 때 슈카만 1주기 방송할 생각으로 마음이 설렜냐는 질문에 전...
# 243  푸틴이 우크라이나의 영토합병에 서명하면서 연설을 했는데 러시아 국민 수백만 명의 의...
# 283  러시아가 우크라이나를 침공하면서 시작된 일이 2022년 2월 24일 러시아가 우크라...
# 101  러시아가 한국의 우크라이나 무기 제공에 대해 위협을 했는데 한국이 우크라이나에 무기...
#
#                                               combined  \
# 255  Title: 세계가 놀란 우크라이나의 반격; Content: 러시아가 쇼킹상태라고 ...
# 133  Title: 한국식 휴전 모델? 교착상태에 빠지는 우크라이나 전쟁; Content:...
# 243  Title: 아 제발.. 고조되는 러시아발 핵위협; Content: 푸틴이 우크라이...
# 283  Title: 형제여.. 폴란드, 대한민국 무기 약 20조원 구매; Content: ...
# 101  Title: 나으리 우리는 수출만 했을 뿐입니다.; Content: 러시아가 한국의...
#
#                                              embedding  similarity
# 255  [-0.015291125870511263, -0.0131246627577784, 0...    0.895538
# 133  [-0.008166731693582762, -0.0225195596563055, 0...    0.886553
# 243  [-0.018262905206603192, -0.015384221712463737,...    0.869410
# 283  [-0.020319655037094226, -0.026926821040133858,...    0.868760
# 101  [-0.015947872144958, -0.009386615458136165, 0....    0.865645

# %% [markdown]
# ## 검색 결과와 함께 질문하기!
#   - 질문과 유사한 컨텐츠를 검색합니다.
#   - GPT 의 프롬프트에 유사한 결과를 함께 넣어 줍니다.
#   - GPT 가 학습할 때 없었던 정보이지만, 이렇게 같이 넣어주면 GPT 가 누락되지 않은 정보를 이용하여 대답을 할 수 있습니다.

# %%
GPT_MODEL="gpt-4"
def num_tokens(text: str, model: str = GPT_MODEL) -> int:
    """Return the number of tokens in a string."""
    encoding = tiktoken.encoding_for_model(model)
    return len(encoding.encode(text))


def query_message(
    query: str,
    df: pd.DataFrame,
    model: str,
    token_budget: int
) -> str:
    """Return a message for GPT, with relevant source texts pulled from a dataframe."""
    
    results = search_video(df, query, n=5)
    strings = results['combined']
    
    introduction = 'Use the below articles on the 슈카월드 to answer the subsequent question. If the answer cannot be found in the articles, write "I could not find an answer."'
    question = f"\n\nQuestion: {query}"
    message = introduction
    for string in strings:
        next_article = f'\n\n:\n"""\n{string}\n"""'
        print("Tokens in Use : ", num_tokens(message + next_article + question, model=model))
        if (
            num_tokens(message + next_article + question, model=model)
            > token_budget
        ):
            
            break
        else:
            message += next_article
    return message + question

def ask(
    query: str,
    df: pd.DataFrame = df,
    model: str = GPT_MODEL,
    token_budget: int = 8192 - 500,
    print_message: bool = False,
) -> str:
    """Answers a query using GPT and a dataframe of relevant texts and embeddings."""
    message = query_message(query, df, model=model, token_budget=token_budget)
    if print_message:
        print(message)
    messages = [
        {"role": "system", "content": "You answer questions about 슈카의 유투브 내용"},
        {"role": "user", "content": message},
    ]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0
    )
    response_message = response["choices"][0]["message"]["content"]
    return response_message

# %%
# set print_message=True to see the source text GPT was working off of
ask('우크라이나와 러시아의 전쟁은 어떻게 되어가고 있나요?', model="gpt-4", print_message=True)
# Out:
# Tokens in Use :  1357
# Tokens in Use :  2662
# Tokens in Use :  3613
# Tokens in Use :  5774
# Tokens in Use :  6827
# Use the below articles on the 슈카월드 to answer the subsequent question. If the answer cannot be found in the articles, write "I could not find an answer."
#
# :
# """
# Title: 세계가 놀란 우크라이나의 반격; Content: 러시아가 쇼킹상태라고 하는 우크라이나의 반격 때문에 어떤 일이 있었는지 살펴보도록 하자 하르키우라는 곳에서 벌어진 우크라이나의 군대에 갑작스러운 반격의 성공이 전략에 대한 분석을 바꾸고 있다는 기사가 있다 우크라이나 수도 동부는 하루 만에 돌파하고 몰도바까지 후루룩 해서 우크라이나를 내륙국가로 만들겠다는 원대한 계획을 얘기했지만 현실은 아직도 이러고 있다. 우크라이나군은 이지움이라는 전략도시를 쳐들어가서 러시아의 보급선을 끊는 것을 목표로 하고 있다 러시아의 보급선을 끊는 것을 아래로 보급선을 끊는 것을 목표로 하고 있다 우크라이나 군대가 지움에 Enter 입장하고 있는 상황이기 때문에 우크라이나 군대가 실시간으로 지움에 Enter 입장하고 있는 상황이다
�긴 한다고 했다. 한국이 K2 생산 공장을 짓는 컨소시엄도 합의가 완료됐고 폴란드에서 한국이 K2 생산 공장을 짓는 컨소시엄도 합의가 완료됐다. 한국은 세계 4위 무기 수출국이 되기 충분하다고 미국 언론들이 얘기했다 한국은 8위인데 방위산업체 수출량이 4위까지 오를 수 있고 세계 4위 무기 수출국이 되기 충분하다고 포방부라는 별명이 있었는데 화력에 미친 나라라고 무시를 받은 줄 알았는데 탱크와 자주포 같은 걸로 밀어붙이는 게 언제적 전략인지 지금도 참호전을 하고 있다. 우리는 울트라 하이 슈퍼파워 성능을 보이는 초고성능 무기를 개발하고 있다. 대한민국 국방부 대변인은 우크라이나에 살상 무기를 지원하지 않는다고 했고 폴란드에 수출하는 총탄의 최종 사용자는 폴란드래 우리가 준 걸로 지원한 것이 아니기 때문에 그렇다고 했다. 폴란드 총리 아저씨가 한국을 안심시켜 무기를 받아야 된다는 말에 동맹 조약을 심각하게 생각한다고 했다. 중국이 현상 변경을 하지 말라고 하자 대만 문제는 국내 이슈가 아니라 국내 이슈다라고 발끈했고 핵심 이익 중에 핵심 이익이니 외부자는 간섭하지 말라고 불용치훼라는 단어를 사용했다고 했다. 현대차 중국 공장 돌리게 해 줘야 하는데 현대차 중국 공장 돌리게 해 줘야 하는데 립서비스를 해야 걸려있지 않을까라는 부정적인 생각이 들지만 받아오면 되는 상황에 있다 한미 정상회담이 나올 것이다.
# """
#
# Question: 우크라이나와 러시아의 전쟁은 어떻게 되어가고 있나요?
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 # set print_message=True to see the source text GPT was working off of
# ----> 2 ask('우크라이나와 러시아의 전쟁은 어떻게 되어가고 있나요?', model="gpt-4", print_message=True)
#
# Cell In[8], line 50, in ask(query, df, model, token_budget, print_message)
#      45     print(message)
#      46 messages = [
#      47     {"role": "system", "content": "You answer questions about 슈카의 유투브 내용"},
#      48     {"role": "user", "content": message},
#      49 ]
# ---> 50 response = openai.ChatCompletion.create(
#      51     model=model,
#      52     messages=messages,
#      53     temperature=0
#      54 )
#      55 response_message = response["choices"][0]["message"]["content"]
#      56 return response_message
#
# File ~\anaconda3\lib\site-packages\openai\_utils\_proxy.py:22, in LazyProxy.__getattr__(self, attr)
#      21 def __getattr__(self, attr: str) -> object:
# ---> 22     return getattr(self.__get_proxied__(), attr)
#
# File ~\anaconda3\lib\site-packages\openai\_utils\_proxy.py:43, in LazyProxy.__get_proxied__(self)
#      41 def __get_proxied__(self) -> T:
#      42     if not self.should_cache:
# ---> 43         return self.__load__()
#      45     proxied = self.__proxied
#      46     if proxied is not None:
#
# File ~\anaconda3\lib\site-packages\openai\lib\_old_api.py:33, in APIRemovedInV1Proxy.__load__(self)
#      31 @override
#      32 def __load__(self) -> None:
# ---> 33     raise APIRemovedInV1(symbol=self._symbol)
#
# APIRemovedInV1:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
