# %% [markdown]
# # 데이터 불러오기/살펴보기
#
# ### 주요 내용
#
# 1. csv, xlsx 파일 불러오기
# 2. 데이터 살펴보기
# 3. DRM 보안 파일 불러오기
#
# <br>
#
# ### 목표
# 1. 분석에 필요한 데이터를 python으로 불러올 수 있다.
# 2. 데이터의 일부나 특성을 확인할 수 있다.
#
#
# <br>
# <hr>
# <br>

# %% [markdown]
# ## 1. 파일 불러와서 살펴보기
#
# **pandas** 라이브러리의 *read_csv()* 등의 함수를 활용해서 데이터 불러오기 가능
# 아래의 표현들을 활용해서 데이터 파일의 경로 지정 필요
#
# * `/` : **root**. Windows에서는 C:\
# * `~/` : 사용자 폴더. Windows에서는 C:\Users\사용자계정이름
# * `./` : 현재 작업 폴더(working directory), 별도로 작업하지 않은 경우 생략 가능
# * `../` : 현재 폴더의 상위 폴더
#
#
# `바탕화면`처럼 익숙한 곳에 새로운 폴더를 만들고, 데이터 파일을 옮겨서 작업하는 것을 추천

# %%
# 현재 작업 폴더 확인
    ## print working directory
# %pwd
# Out:
# 'C:\\Users\\jhpark\\Desktop\\7_fastcampus\\0620_강의자료\\실습자료_Python 데이터 분석'

# %% [markdown]
# <br>
#
# ### 1.1. CSV 파일 불러오기
#
# **pandas** 라이브러리 불러오기

# %%
import pandas as pd

# %%
# pandas의 read_csv( ) 활용
#df_ins= pd.read_csv("./data/insurance.csv")
df_ins= pd.read_csv("data/insurance.csv")
df_ins    
    ## 경로가 중요! 
    ## ./ : ipynb 노트북 파일 폴더
    ## ./ 생략 가능
    ## Tab으로 자동 완성 기능 활용 가능
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
# 타입 확인
type(df_ins)
    ## "DataFrame"
# Out:
# pandas.core.frame.DataFrame

# %%
# 메서드의 확인(마침표 뒤에서 Tab 누르기)
df_ins.

# %% [markdown]
# <br>
#
# ### 1.2. 데이터 살펴보기

# %%
# head( )로 앞 몇개 관측치 확인
df_ins.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# tail( )로 끝 몇 개 관측치 확인
df_ins.tail(n=3)
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
# 관측치/ 변수 개수 확인
df_ins.shape
# Out:
# (1338, 7)

# %%
# 관측치 개수만 확인
df_ins.shape[1]
# Out:
# 7

# %%
# index(행 이름) 확인
df_ins.index
# Out:
# RangeIndex(start=0, stop=1338, step=1)

# %%
# columns(변수 이름) 확인
df_ins.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
# 변수 형식 확인
df_ins.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %% [markdown]
# <br>
#
# #### [실습] data 폴더의 PulseRates.csv를 불러와서 df_pr로 저장하기
#
# 이후 자유롭게 데이터 탐색하기

# %%
df_pulse = pd.read_csv("./data/PulseRates.csv")

# %%
df_pulse.head()
# Out:
#    Height  Weight  Age  Gender  Smokes  Alcohol  Exercise  Ran  Pulse1  \
# 0     173    57.0   18       2       2        1         2    2    86.0
# 1     179    58.0   19       2       2        1         2    1    82.0
# 2     167    62.0   18       2       2        1         1    1    96.0
# 3     195    84.0   18       1       2        1         1    2    71.0
# 4     173    64.0   18       2       2        1         3    2    90.0
#
#    Pulse2  Year
# 0    88.0    93
# 1   150.0    93
# 2   176.0    93
# 3    73.0    93
# 4    88.0    93

# %%
df_pulse.columns
# Out:
# Index(['Height', 'Weight', 'Age', 'Gender', 'Smokes', 'Alcohol', 'Exercise',
#        'Ran', 'Pulse1', 'Pulse2', 'Year'],
#       dtype='object')

# %% [markdown]
# #### [참고] Encoding 지정 및 index, header 지정

# %%
# 인코딩(글자 저장 방법) 오류 발생
    ## UnicodeDecodeError  'utf-8' codec can't decode byte 0xbc in position 1: invalid start byte
pd.read_csv('data/고용지표_20221115084415.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[22], line 3
#       1 # 인코딩(글자 저장 방법) 오류 발생
#       2     ## UnicodeDecodeError  'utf-8' codec can't decode byte 0xbc in position 1: invalid start byte
# ----> 3 pd.read_csv('data/고용지표_20221115084415.csv')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1753, in TextFileReader._make_engine(self, f, engine)
#    1750     raise ValueError(msg)
#    1752 try:
# -> 1753     return mapping[engine](f, **self.options)
#    1754 except Exception:
#    1755     if self.handles is not None:
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:79, in CParserWrapper.__init__(self, src, **kwds)
#      76     kwds.pop(key, None)
#      78 kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
# ---> 79 self._reader = parsers.TextReader(src, **kwds)
#      81 self.unnamed_cols = self._reader.unnamed_cols
#      83 # error: Cannot determine type of 'names'
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:547, in pandas._libs.parsers.TextReader.__cinit__()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:636, in pandas._libs.parsers.TextReader._get_header()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:852, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:1965, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xbc in position 1: invalid start byte

# %%
# 옵션 encoding='CP949' 추가
pd.read_csv('data/고용지표_20221115084415.csv', encoding='CP949')
# Out:
#    성별(1) 2021. 08 2021. 08.1 2021. 08.2 2021. 09 2021. 09.1 2021. 09.2  \
# 0  성별(1)  경제활동참가율        실업률        고용률  경제활동참가율        실업률        고용률
# 1     합계     61.7        4.0       59.2     61.9        3.6       59.7
# 2     남자     70.0        4.1       67.1     70.3        3.8       67.7
# 3     여자     54.2        3.9       52.1     54.3        3.4       52.5
#
#   2021. 10 2021. 10.1 2021. 10.2  ... 2022. 04.2 2022. 05 2022. 05.1  \
# 0  경제활동참가율        실업률        고용률  ...        고용률  경제활동참가율        실업률
# 1     62.1        4.2       59.5  ...       60.4     63.0        3.5
# 2     70.6        4.6       67.3  ...       68.7     71.8        3.7
# 3     54.5        3.7       52.5  ...       52.9     55.0        3.3
#
#   2022. 05.2 2022. 06 2022. 06.1 2022. 06.2 2022. 07 2022. 07.1 2022. 07.2
# 0        고용률  경제활동참가율        실업률        고용률  경제활동참가율        실업률        고용률
# 1       60.8     63.0        3.4       60.8     62.9        3.3       60.9
# 2       69.2     71.6        3.3       69.2     71.3        3.4       68.9
# 3       53.2     55.2        3.6       53.2     55.4        3.1         53
#
# [4 rows x 37 columns]

# %%
# index, header 지정
pd.read_csv('data/고용지표_20221115084415.csv', encoding='CP949', index_col=0, header=[0,1])
# Out:
# 성별(1) 2021. 08            2021. 09            2021. 10            2021. 11  \
# 성별(1)  경제활동참가율  실업률   고용률  경제활동참가율  실업률   고용률  경제활동참가율  실업률   고용률  경제활동참가율
# 합계        61.7  4.0  59.2     61.9  3.6  59.7     62.1  4.2  59.5     62.5
# 남자        70.0  4.1  67.1     70.3  3.8  67.7     70.6  4.6  67.3     71.2
# 여자        54.2  3.9  52.1     54.3  3.4  52.5     54.5  3.7  52.5     54.6
#
# 성별(1)  ... 2022. 04 2022. 05            2022. 06            2022. 07       \
# 성별(1)  ...      고용률  경제활동참가율  실업률   고용률  경제활동참가율  실업률   고용률  경제활동참가율  실업률
# 합계     ...     60.4     63.0  3.5  60.8     63.0  3.4  60.8     62.9  3.3
# 남자     ...     68.7     71.8  3.7  69.2     71.6  3.3  69.2     71.3  3.4
# 여자     ...     52.9     55.0  3.3  53.2     55.2  3.6  53.2     55.4  3.1
#
# 성별(1)
# 성별(1)   고용률
# 합계     60.9
# 남자     68.9
# 여자     53.0
#
# [3 rows x 36 columns]

# %% [markdown]
# <br>
#
#
# ### 1.3. Excel 파일 불러오기
#
# `Excel` 파일은 구버전의 **xls**와 새로운 버전의 **xlsx**로 구분하며 추가 라이브러리 `xlrd`와 `openpyxl` 설치 필수
#  이후 pandas의 `read_excel( )`을 사용 가능
#  > pandas 1.3 이전 버전에서는 **xlsx** 파일을 불러올 때 함수 안에 `, engine='openpyxl'`를 추가해야할 수도 있습니다.

# %%
# 무난한 첫번째 시트 데이터 불러오기
sheet1 = pd.read_excel('./data/test.xlsx')
sheet1
# Out:
#    ID  Var1  Var2  Var3
# 0   1    11    45    75
# 1   2    54    32    34
# 2   4    65    43    54

# %%
# 시트 번호 지정하고 2줄 무시하기
sheet2 = pd.read_excel('data/test.xlsx', sheet_name=1, skiprows=2)
sheet2
    ## sheet_name : 시트 이름이나 번호 지정, 번호는 0부터 시작
    ## skiprows   : 무시할 행 수
# Out:
#    이름  나이    키
# 0  민서  20  160
# 1  민준  21  175

# %%
# 첫 행부터 데이터가 시작되는 데이터 불러오기
sheet3 = pd.read_excel('data/test.xlsx', sheet_name=2, header=None)
sheet3
    ## header : 첫 행에 변수이름이 저장되었는지 여부
# Out:
#       0   1
# 0  2015  32
# 1  2016  34
# 2  2017   -

# %%
# 첫 행부터 데이터가 시작되는 데이터 불러오면서 변수 이름 지정하기
sheet3 = pd.read_excel('data/test.xlsx', sheet_name=2, header=None, names=['년도','건수'])
sheet3
# Out:
#      년도  건수
# 0  2015  32
# 1  2016  34
# 2  2017   -

# %%
# 결측 저장값 지정하기
sheet3 = pd.read_excel('data/test.xlsx', sheet_name=2, header=None, names=['년도','건수'], na_values='-')
sheet3
    ## NaN : 결측값
# Out:
#      년도    건수
# 0  2015  32.0
# 1  2016  34.0
# 2  2017   NaN

# %% [markdown]
# <br>
#
# ####  [실습] 아래의 사이트에서 관심있는 데이터를 탐색하기
#
# * csv 파일 중 인코딩 관련 에러가 발생할 경우 read_csv( )안에서 `encoding='CP949'` 옵션 추가
# * xlsx의 경우 다운로드한 파일을 열어서 읽기 전용을 해제해야 할 수도 있음
#
#
#
# [공공데이터포털](https://www.data.go.kr/index.do)
#
# [서울 열린데이터 광장](http://data.seoul.go.kr/)
#
# [Dacon](https://dacon.io/)

# %%
pd.read_csv("../../../../Downloads/서울특별시 송파구_치과기공소현황_20230619.csv")

# %%
pd.read_csv("/Users/jhpark/Downloads/서울특별시 송파구_치과기공소현황_20230619.csv", encoding="cp949", index_col=0)
# Out:
#                                 치과기공소명  \
# 순번
# 1   디지털아이콘덴탈랩(Digital iCon Dental LaB)
# 2                          달(DAL)치과기공소
# 3                             EDL치과기공소
# 4                                케이덴탈랩
# 5                      유얼라인 투명교정 치과기공소
# 6                          디지털코리아치과기공소
# 7                              목 치과기공소
# 8                           에스-텍 치과기공소
# 9                           에이플러스치과기공소
# 10                            새로운치과기공소
# 11                             에이엔디덴탈랩
# 12                             유닛치과기공소
# 13                          스마일라인치과기공소
# 14                            이굿플치과기공소
# 15                           디엘큐브치과기공소
# 16                            차오름치과기공소
# 17                             코스치과기공소
# 18                            제이비치과기공소
# 19                         피앤에이치 치과기공소
# 20                            클리어치과기공소
# 21                             네비치과기공소
# 22                             바른치과기공소
# 23                            메이플치과기공소
# 24                    트러스트(Trust)치과기공소
# 25                              연치과기공소
# 26                           이새로 치과기공소
# 27                             미래치과기공소
# 28                    유투스(UTOOTH)치과기공소
# 29                          지르캠프 치과기공소
# 30                              본치과기공소
# 31                           퍼스트 치과기공소
# 32                             복운치과기공소
# 33                             그리치과기공소
# 34                              샘치과기공소
# 35                           좋은하루치과기공소
# 36                       JK(제이케이)치과기공소
# 37                             미소치과기공소
# 38                             지오치과기공소
# 39                           미다듬 치과기공소
# 40                            리더스치과기공소
# 41                            하이텍치과기공소
# 42                            윤원상치과기공소
# 43                           석촌TC치과기공소
# 44                           치아정밀치과기공소
# 45                             심미치과기공소
# 46                           골드캐슬치과기공소
# 47                           B.L 치과기공소
# 48                              웰치과기공소
# 49                             동성치과기공소
# 50                             신화치과기공소
# 51                             청산치과기공소
# 52                             으뜸치과기공소
# 53                              수치과기공소
# 54                       티타늄 코리아 치과기공소
# 55                           크리아트치과기공소
# 56                             열린치과기공소
# 57                              미치과기공소
# 58                            엘리트치과기공소
# 59                             쌍용치과기공소
# 60                          덴텍매니아치과기공소
#
#                                              소재지(도로명)
# 순번
# 1               서울특별시 송파구 백제고분로28길 33, 202호 일부호 (삼전동)
# 2                   서울특별시 송파구 동남로 102, 레이102 5층 (문정동)
# 3                         서울특별시 송파구 풍성로 69, 1층층 (풍납동)
# 4                     서울특별시 송파구 송이로 97, 화영빌딩 2층 (가락동)
# 5            서울특별시 송파구 법원로4길 5, 송파법조타운푸르지오 318호 (문정동)
# 6                       서울특별시 송파구 송이로 102-1, 3층 (가락동)
# 7                  서울특별시 송파구 송이로17길 54-27, 302호 (가락동)
# 8                       서울특별시 송파구 동남로 113, 401호 (가락동)
# 9                   서울특별시 송파구 올림픽로32길 22-22, 4층 (방이동)
# 10                  서울특별시 송파구 삼학사로8길 5, 지층 B03호 (석촌동)
# 11                      서울특별시 송파구 오금로46길 22, 2층 (가락동)
# 12                     서울특별시 송파구 가락로18길 4-1, 2층 (송파동)
# 13                    서울특별시 송파구 송이로 95, 화영빌딩 4층 (가락동)
# 14                 서울특별시 송파구 거마로2길 3-4, 2층 201호 (거여동)
# 15              서울특별시 송파구 오금로 216, 타워빌딩 3층 302호 (송파동)
# 16  서울특별시 송파구 법원로 128, 문정에스케이브이원지엘메트로시티 B동 9층 908,...
# 17                     서울특별시 송파구 풍성로20길 5, 지하1층 (풍납동)
# 18                  서울특별시 송파구 올림픽로 585, 2층 202호 (풍납동)
# 19     서울특별시 송파구 법원로9길 26, C동 12층 2호 (문정동, 에이치비지니스파크)
# 20   서울특별시 송파구 법원로11길 25, B동 4층 401호 (문정동, 에이치비지니스파크)
# 21                  서울특별시 송파구 백제고분로28길 33, 202호 (삼전동)
# 22               서울특별시 송파구 오금로11길 51, 502호 (방이동, 이레로)
# 23             서울특별시 송파구 중대로 197, 3층 301호 (가락동, 삼석빌딩)
# 24          서울특별시 송파구 토성로15길 3-3, 2층 202호 (풍납동, 선무빌딩)
# 25              서울특별시 송파구 양산로 14, 세신거여종합상가 203호 (거여동)
# 26                    서울특별시 송파구 백제고분로48길 39, 4층 (방이동)
# 27                      서울특별시 송파구 동남로 209, 104호 (가락동)
# 28            서울특별시 송파구 백제고분로 426, 백상빌딩 2층 201호 (송파동)
# 29         서울특별시 송파구 백제고분로7길 6-5, 남미빌딩 301,401호 (잠실동)
# 30              서울특별시 송파구 백제고분로45길 6 (송파동, 은진빌딩 302호)
# 31                    서울특별시 송파구 백제고분로41길 28, 2층 (송파동)
# 32                      서울특별시 송파구 중대로33길 18, 2층 (오금동)
# 33                    서울특별시 송파구 가락로16길 2-13, 2층 (석촌동)
# 34              서울특별시 송파구 백제고분로12길 6, 세화빌딩 402호 (잠실동)
# 35               서울특별시 송파구 백제고분로46길 18, 주영빌딩 2층 (송파동)
# 36                     서울특별시 송파구 올림픽로10길 36, 2층 (잠실동)
# 37                     서울특별시 송파구 가락로16길 2-7, 3층 (석촌동)
# 38           서울특별시 송파구 송파대로40길 1-32, 201호 (송파동, 장안빌딩)
# 39                        서울특별시 송파구 마천로 165, 2층 (오금동)
# 40                    서울특별시 송파구 송이로 97, 화영빌딩 3층 (가락동)
# 41                    서울특별시 송파구 삼전로13길 29-1, 2층 (잠실동)
# 42          서울특별시 송파구 위례성대로12길 28, 광림빌딩 4층 403호 (방이동)
# 43                서울특별시 송파구 송파대로49길 53, 2층 202호 (석촌동)
# 44                       서울특별시 송파구 동남로17길 5, 3층 (가락동)
# 45                        서울특별시 송파구 동남로8길 5, 2층 (문정동)
# 46                 서울특별시 송파구 오금로13길 12 (방이동, 명성빌딩 3층)
# 47                   서울특별시 송파구 오금로 146 (송파동, 그린상가 2층)
# 48            서울특별시 송파구 위례성대로12길 28, 402호 (방이동, 광림빌딩)
# 49                      서울특별시 송파구 백제고분로7길 32-14 (잠실동)
# 50                       서울특별시 송파구 마천로51길 1, 2층 (마천동)
# 51               서울특별시 송파구 백제고분로9길 26, 3층 (잠실동, 매은빌딩)
# 52                       서울특별시 송파구 올림픽로32길 22-5 (방이동)
# 53                  서울특별시 송파구 동남로3길 17-14, 201호 (가락동)
# 54                       서울특별시 송파구 송파대로 406, 4층 (송파동)
# 55            서울특별시 송파구 동남로24길 15 (오금동, 이조빌딩 2층 202호)
# 56                          서울특별시 송파구 오금로34길 10 (가락동)
# 57          서울특별시 송파구 백제고분로46길 8, 4층 401호 (송파동, 서암빌딩)
# 58                             서울특별시 송파구 풍성로 69 (풍납동)
# 59                    서울특별시 송파구 석촌호수로18길 24, 3층 (석촌동)
# 60                       서울특별시 송파구 마천로26길 6, 3층 (오금동)

# %% [markdown]
# ## 2.  DRM 보안 적용된 Excel 파일 불러오기

# %% [markdown]
# ### 2.1. pywin32 활용

# %%
import pandas as pd
import win32com.client as win32
import os 

# Excel 실행
excel=win32.Dispatch('Excel.Application')   

# 경로 지정 및 파일 열기
filepath = os.getcwd() +'/data/test.xlsx'
wb = excel.Workbooks.Open(filepath)

filepath

# %%
# Sheet 지정
ws = wb.Worksheets(1) 

# 전체 행, 열 수 확인
nRow = ws.UsedRange.Rows.Count 
nColumn = ws.UsedRange.Columns.Count 

# 불러올 범위 지정
listValue = ws.Range(ws.Cells(1,1) , ws.Cells(nRow,nColumn)).Value
pd.DataFrame(listValue[1:] , columns=listValue[0])

# %%
# Excel 종료
excel.Quit()

# %% [markdown]
# <br>
#
# 한번에 실행

# %%
import pandas as pd
import win32com.client as win32
import os 

# Excel 실행
excel=win32.Dispatch('Excel.Application')   

# 경로 지정 및 파일 열기
filepath = os.getcwd() +'/data/test.xlsx'
wb = excel.Workbooks.Open(filepath)

# Sheet 지정
ws = wb.Worksheets(1) 

# 전체 행, 열 수 확인
nRow = ws.UsedRange.Rows.Count 
nColumn = ws.UsedRange.Columns.Count 

# 불러올 범위 지정
listValue = ws.Range(ws.Cells(1,1) , ws.Cells(nRow,nColumn)).Value
df_drm = pd.DataFrame(listValue[1:] , columns=listValue[0]) 

excel.Quit()     

df_drm

# %% [markdown]
# <br>
# <br>
#
# ### 2.2. xlwings 라이브러리 활용
#
# + 장점: VBA 연동 가능

# %%
# 라이브러리 설치
# !pip install xlwings

# %%
# 라이브러리 불러오기
import xlwings as xw
import pandas as pd
import os

# %%
# Excel 파일 열기
# filepath = os.getcwd() +'/data/test.xlsx'
book = xw.Book('./data/test.xlsx')

# %%
# Sheet 선택
sheet = book.sheets[0]    

# 전체 데이터 데이터 불러오기
df_drm = sheet.used_range.options(pd.DataFrame, index = False).value
df_drm

# %%
# 특정 부분만 불러오기
sheet = book.sheets[1]    
df_drm = sheet.range("A3:C5").options(pd.DataFrame, index = False).value
df_drm

# %%
# 종료
xw.apps.active.quit()

# %% [markdown]
# #### End of script
